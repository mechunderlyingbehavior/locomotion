# %% [markdown]
# ## Path Setup
# First, we make sure that our path is setup. This is to check if we've manually installed our library correctly.

# %%
import sys
import os
PATH_TO_DIRECTORY = os.getcwd()
sys.path.append(PATH_TO_DIRECTORY)

# %%
# If this works, then we're good to go!
import locomotion
# Out:
# Importing the dtw module. When using in academic works please cite:
#   T. Giorgino. Computing and Visualizing Dynamic Time Warping Alignments in R: The dtw Package.
#   J. Stat. Soft., doi:10.18637/jss.v031.i07.

# %% [markdown]
# ## Data Setup

# %%
# No need to touch this
species = "medaka"
exp_type = "SS"
dim_x = 200
dim_y = 100
frames_per_sec = 20
pixels_per_mm = 1.6
start_time = 0
end_time = 10
baseline_start_time = 0
baseline_end_time = 2

import json
jsonItems = [{
    "name": "SS_01",
    "data_file_location": PATH_TO_DIRECTORY + "/samples/sample_data/SS_01.dat",
    "animal_attributes":
    {
      "species": species,
      "exp_type": exp_type,
      "ID": "01",
      "control_group": "False"
    },
    "capture_attributes": 
    {
      "dim_x": dim_x,
      "dim_y": dim_y,
      "pixels_per_mm": pixels_per_mm,
      "frames_per_sec": frames_per_sec,
      "start_time": start_time,
      "end_time": end_time,
      "baseline_start_time": baseline_start_time,
      "baseline_end_time": baseline_end_time
    }
  },
{
    "name": "SS_02",
    "data_file_location": PATH_TO_DIRECTORY + "/samples/sample_data/SS_02.dat",
    "animal_attributes":
    {
      "species": species,
      "exp_type": exp_type,
      "ID": "02",
      "control_group": "False"
    },
    "capture_attributes": 
    {
      "dim_x": dim_x,
      "dim_y": dim_y,
      "pixels_per_mm": pixels_per_mm,
      "frames_per_sec": frames_per_sec,
      "start_time": start_time,
      "end_time": end_time,
      "baseline_start_time": baseline_start_time,
      "baseline_end_time": baseline_end_time
    }
  },
{
    "name": "NSS_01",
    "data_file_location": PATH_TO_DIRECTORY + "/samples/sample_data/NSS_01.dat",
    "animal_attributes":
    {
      "species": species,
      "exp_type": exp_type,
      "ID": "01",
      "control_group": "True"
    },
    "capture_attributes": 
    {
      "dim_x": dim_x,
      "dim_y": dim_y,
      "pixels_per_mm": pixels_per_mm,
      "frames_per_sec": frames_per_sec,
      "start_time": start_time,
      "end_time": end_time,
      "baseline_start_time": baseline_start_time,
      "baseline_end_time": baseline_end_time
    }
  },
{
    "name": "NSS_02",
    "data_file_location": PATH_TO_DIRECTORY + "/samples/sample_data/NSS_02.dat",
    "animal_attributes":
    {
      "species": species,
      "exp_type": exp_type,
      "ID": "02",
      "control_group": "True"
    },
    "capture_attributes": 
    {
      "dim_x": dim_x,
      "dim_y": dim_y,
      "pixels_per_mm": pixels_per_mm,
      "frames_per_sec": frames_per_sec,
      "start_time": start_time,
      "end_time": end_time,
      "baseline_start_time": baseline_start_time,
      "baseline_end_time": baseline_end_time
    }
  }]

outfilename = PATH_TO_DIRECTORY + "/samples/sample_check.json"
jsonstr = json.dumps(jsonItems, indent=4)
with open(outfilename, "w") as outfile:
    outfile.write(jsonstr)
    print("Wrote the information entered into %s" % outfilename)
# Out:
# Wrote the information entered into /home/zhongxuan/ync/compgeom/locomotion_package/samples/sample_check.json

# %%
info_file = outfilename
animals = locomotion.get_animal_objs( info_file )
for a in animals:
  locomotion.trajectory.get_curve_data( a )
# Out:
# LOG: Extracting coordinates for Animal SS_01...
# LOG: Extracting coordinates for Animal SS_02...
# LOG: Extracting coordinates for Animal NSS_01...
# LOG: Extracting coordinates for Animal NSS_02...
# /home/zhongxuan/ync/compgeom/locomotion_package/locomotion/animal.py:179: UserWarning:
#
# get_raw_vals: End frame comes after existing frames. Defaulting to the final frame stored.

# %%
variables = ['Y','Velocity','Curvature']
norm_mode = 'spec'
number_of_comparisons_per_animal, specified_durations = 100, None
start_time, end_time = 0, 1
distances = locomotion.trajectory.compute_all_bdd(animals,
                                                variables,
                                                start_time,
                                                end_time,
                                                norm_mode)
# Out:
# LOG: Applying DTW to the data from files SS_01 and SS_02...
# LOG: distance between SS_01 and SS_02: 0.27359
# LOG: Applying DTW to the data from files SS_01 and NSS_01...
# LOG: distance between SS_01 and NSS_01: 0.30341
# LOG: Applying DTW to the data from files SS_01 and NSS_02...
# LOG: distance between SS_01 and NSS_02: 0.31104
# LOG: Applying DTW to the data from files SS_02 and NSS_01...
# LOG: distance between SS_02 and NSS_01: 0.32123
# LOG: Applying DTW to the data from files SS_02 and NSS_02...
# LOG: distance between SS_02 and NSS_02: 0.34324
# LOG: Applying DTW to the data from files NSS_01 and NSS_02...
# LOG: distance between NSS_01 and NSS_02: 0.34532

# %%
output_directory, outfile_name = PATH_TO_DIRECTORY + "/results", "results"
try: # Safety check to ensure that data folder exists, and makes it otherwise.
    os.mkdir(output_directory)
except FileExistsError:
    pass
sort_table, square_table = False, False
color_min, color_max = 0.1, 0.5
locomotion.write.post_process(animals,
                             distances,
                             output_directory,
                             outfile_name,
                             sort_table,
                             square_table,
                             color_min,
                             color_max)
# Out:
# LOG: Wrote the results in /home/zhongxuan/ync/compgeom/locomotion_package/results/results.csv
# /home/zhongxuan/anaconda3/lib/python3.7/site-packages/plotly/graph_objs/_deprecations.py:410: DeprecationWarning:
#
# plotly.graph_objs.Margin is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.Margin
# LOG: Plot the heatmap in /home/zhongxuan/ync/compgeom/locomotion_package/results/results.html

# %%
print(distances)
# Print result should be similar to the following:
# [['', 0.20282969626295833, 0.2860520059340922, 0.17829970331490627], 
# ['', '', 0.24460085826104375, 0.23165243606422234], 
# ['', '', '', 0.27422508097123505], ['', '', '', '']]
# Out:
# [['', 0.273591022712512, 0.30341115091473103, 0.31104216326485784], ['', '', 0.32122740439633457, 0.34324297737114157], ['', '', '', 0.3453162881209742], ['', '', '', '']]

# %%
grid_size, start_time, end_time = 10, 0, 2
for a in animals:
    locomotion.heatmap.get_surface_data(a, grid_size, start_time, end_time)
# Out:
# Calculating heatmap for SS_01...
# Calculating triangulation for SS_01...
# Calculating flattened coordinates for SS_01...
# LOG: Distance of original centroid to origin is 0.024375412663795365. Moving closer to origin.
# LOG: Distance of original centroid to origin is 5.594626135868938e-05. Moving closer to origin.
# Calculating vertex BFS and triangle adjacency for SS_01...
# Calculating heatmap for SS_02...
# WARNING: X data is out of bounds. Frame #1, x=80.907500
# WARNING: X data is out of bounds. Frame #2, x=80.460625
# WARNING: X data is out of bounds. Frame #3, x=80.222500
# WARNING: X data is out of bounds. Frame #4, x=75.091875
# WARNING: X data is out of bounds. Frame #5, x=72.893125
# WARNING: X data is out of bounds. Frame #6, x=72.085625
# WARNING: X data is out of bounds. Frame #7, x=68.235625
# WARNING: X data is out of bounds. Frame #8, x=68.946875
# WARNING: X data is out of bounds. Frame #9, x=71.944375
# WARNING: X data is out of bounds. Frame #10, x=76.274375
# WARNING: X data is out of bounds. Frame #11, x=79.311250
# WARNING: X data is out of bounds. Frame #12, x=85.290000
# WARNING: X data is out of bounds. Frame #13, x=89.660000
# WARNING: Y data is out of bounds. Frame #22, x=31.324687
# WARNING: Y data is out of bounds. Frame #23, x=31.070187
# WARNING: Y data is out of bounds. Frame #24, x=31.211625
# Calculating triangulation for SS_02...
# Calculating flattened coordinates for SS_02...
# LOG: Distance of original centroid to origin is 0.003757595154021633. Moving closer to origin.
# Calculating vertex BFS and triangle adjacency for SS_02...
# Calculating heatmap for NSS_01...
# Calculating triangulation for NSS_01...
# Calculating flattened coordinates for NSS_01...
# LOG: Distance of original centroid to origin is 0.0003261147681144059. Moving closer to origin.
# Calculating vertex BFS and triangle adjacency for NSS_01...
# Calculating heatmap for NSS_02...
# Calculating triangulation for NSS_02...
# Calculating flattened coordinates for NSS_02...
# LOG: Distance of original centroid to origin is 0.022038934470546043. Moving closer to origin.
# LOG: Distance of original centroid to origin is 0.0003498798333979792. Moving closer to origin.
# Calculating vertex BFS and triangle adjacency for NSS_02...
# /home/zhongxuan/ync/compgeom/locomotion_package/locomotion/animal.py:179: UserWarning:
#
# get_raw_vals: End frame comes after existing frames. Defaulting to the final frame stored.

# %%
distances = locomotion.heatmap.compute_all_csd(animals)
# Out:
# Measuring conformal spatiotemporal distance between heat maps of SS_01 and SS_02...
# /home/zhongxuan/anaconda3/lib/python3.7/site-packages/scipy/optimize/_minimize.py:516: RuntimeWarning:
#
# Method Powell cannot handle constraints nor bounds.
# WARNING: no triangle found for interior vertex 161. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 183. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 171. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 182. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 181. Assigning closest vertex instead.
# WARNING: Central vertex in Animal 1 is not contained in any triangle in Animal 0.
# WARNING: no triangle found for interior vertex 94. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 95. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 104. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 106. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 115. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 116. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 83. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 84. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 93. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 85. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 96. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 103. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 114. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 107. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 117. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 125. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 126. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 127. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 72. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 73. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 82. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 74. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 92. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 75. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 86. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 97. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 102. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 113. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 124. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 108. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 118. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 128. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 135. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 136. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 137. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 138. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 61. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 62. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 71. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 63. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 81. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 64. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 91. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 65. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 76. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 87. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 98. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 101. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 112. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 123. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 134. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 145. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 146. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 147. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 148. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 51. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 52. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 53. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 54. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 55. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 66. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 77. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 88. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 111. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 122. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 133. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 144. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 155. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 156. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 157. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 158. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 41. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 42. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 43. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 44. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 45. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 56. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 67. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 78. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 121. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 132. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 143. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 154. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 165. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 166. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 167. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 168. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 31. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 32. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 33. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 34. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 35. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 46. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 57. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 68. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 131. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 142. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 153. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 164. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 175. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 176. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 177. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 178. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 21. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 22. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 23. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 24. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 25. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 36. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 47. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 58. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 141. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 152. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 163. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 174. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 185. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 186. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 187. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 188. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 11. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 12. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 13. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 14. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 15. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 26. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 37. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 48. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 151. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 162. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 173. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 184. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 16. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 27. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex
Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 108. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 118. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 128. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 135. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 136. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 137. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 138. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 61. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 62. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 71. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 63. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 81. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 64. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 91. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 65. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 76. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 87. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 98. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 101. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 112. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 123. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 134. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 145. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 146. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 147. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 148. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 51. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 52. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 53. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 54. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 55. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 66. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 77. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 88. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 111. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 122. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 133. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 144. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 155. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 156. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 157. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 158. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 41. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 42. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 43. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 44. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 45. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 56. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 67. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 78. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 121. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 132. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 143. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 154. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 165. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 166. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 167. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 168. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 31. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 32. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 33. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 34. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 35. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 46. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 57. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 68. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 131. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 142. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 153. Assigning closest vertex instead.
# ...
# WARNING: no triangle found for interior vertex 178. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 21. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 22. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 23. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 24. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 25. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 36. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 47. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 58. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 141. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 152. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 163. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 174. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 185. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 186. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 187. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 188. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 11. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 12. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 13. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 14. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 15. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 26. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 37. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 48. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 151. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 162. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 173. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 184. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 16. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 27. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 38. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 161. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 172. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 183. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 17. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 28. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 171. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 182. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 18. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 181. Assigning closest vertex instead.
# WARNING: Central vertex in Animal 1 is not contained in any triangle in Animal 0.
# WARNING: no triangle found for interior vertex 94. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 95. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 104. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 106. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 115. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 116. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 83. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 84. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 93. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 85. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 96. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 103. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 114. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 107. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 117. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 125. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 126. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 127. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 72. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 73. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 82. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 74. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 92. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 75. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 86. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 97. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 102. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 113. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 124. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 108. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 118. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 128. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 135. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 136. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 137. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 138. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 61. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 62. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 71. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 63. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 81. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 64. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 91. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 65. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 76. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 87. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 98. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 101. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 112. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 123. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 134. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 145. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 146. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 147. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 148. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 51. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 52. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 53. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 54. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 55. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 66. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 77. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 88. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 111. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 122. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 133. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 144. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 155. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 156. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 157. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 158. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 41. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 42. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 43. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 44. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 45. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 56. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 67. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 78. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 121. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 132. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 143. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 154. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 165. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 166. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 167. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 168. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 31. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 32. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 33. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 34. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 35. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 46. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 57. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 68. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 131. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 142. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 153. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 164. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 175. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 176. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 177. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 178. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 21. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 22. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 23. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 24. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 25. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 36. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 47. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 58. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 141. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 152. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 163. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 174. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 185. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 186. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 187. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 188. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 11. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 12. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 13. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 14. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 15. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 26. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 37. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 48. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 151. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 162. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 173. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 184. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 16. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 27. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 38. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 161. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 172. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 183. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 17. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 28. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 171. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 182. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 18. Assigning closest vertex instead.
# WARNING: no triangle found for interior vertex 181. Assigning closest vertex instead.
# LOG: Found an optimal (theta, rho) mapping of [-0.13006444 -0.11746533].
# LOG: distance between aligned surfaces of NSS_01 and NSS_02: 0.009

# %%
output_directory, outfile_name = PATH_TO_DIRECTORY + "/results", "results"
sort_table, square_table = False, False
color_min, color_max = 0, 0.02
locomotion.write.post_process(animals,
                             distances,
                             output_directory,
                             outfile_name,
                             sort_table,
                             square_table,
                             color_min,
                             color_max)
# Out:
# LOG: Wrote the results in /home/zhongxuan/ync/compgeom/locomotion_package/results/results.csv
# /home/zhongxuan/anaconda3/lib/python3.7/site-packages/plotly/graph_objs/_deprecations.py:410: DeprecationWarning:
#
# plotly.graph_objs.Margin is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.Margin
# LOG: Plot the heatmap in /home/zhongxuan/ync/compgeom/locomotion_package/results/results.html

# %% [markdown]
# # Once you are done, please remember to clear all outputs with 'Cell > All Output > Clear'
